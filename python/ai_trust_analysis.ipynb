# %% [markdown]
# # Load Data

# %% [markdown]
# # Explore Data

# %% [markdown]
# # Reverse Scoring

# %% [markdown]
# # Create Construct Scores

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# # Correlation Analysis

# %% [markdown]
# # Regression Analysis

# %% [markdown]
# # Visualizations

# %% [markdown]
# # Product Insights
